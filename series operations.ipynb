# %%
import pandas as pd
import numpy as np
df = pd.read_csv("D:\\data science\\pandas\\csv\\nba.csv")
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
ps = pd.Series(df["Name"])
ps.head(10)
# Out:
# 0    Avery Bradley
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %%
a = ps.iloc[1:6]
a
# Out:
# 1      Jae Crowder
# 2     John Holland
# 3      R.J. Hunter
# 4    Jonas Jerebko
# 5     Amir Johnson
# Name: Name, dtype: object

# %%
b = ps.loc[5:9]
b
# Out:
# 5     Amir Johnson
# 6    Jordan Mickey
# 7     Kelly Olynyk
# 8     Terry Rozier
# 9     Marcus Smart
# Name: Name, dtype: object

# %% [markdown]
# <font size="5"><font color="red">now lets do some binary operations on pandas series

# %%
data1 = [10,20,30,40]
data2 = [30,40,50,60]
ps2 = pd.Series(data1)
ps2
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
ps3 = pd.Series(data2)
ps3
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# dtype: int64

# %%
ps4 = ps2.add(ps3,fill_value=0)
ps4
# Out:
# 0     40
# 1     60
# 2     80
# 3    100
# dtype: int64

# %%
# %matplotlib inline
ps2.plot()

# %%
ps3.plot()

# %%
ps4.plot()

# %%
c = df["Age"]
c
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
c.plot()

# %%
d = df["Weight"]
d.plot()

# %%
e = df["Salary"]
e.plot()

# %%
f = df["Number"]
f
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
#        ...
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
f.plot()

# %%
g = df["Height"]
g
# Out:
# 0       6-2
# 1       6-6
# 2       6-5
# 3       6-5
# 4      6-10
#        ...
# 453     6-3
# 454     6-1
# 455     7-3
# 456     7-0
# 457     NaN
# Name: Height, Length: 458, dtype: object

# %%
df.plot()

# %%
e = df.fillna("no value")
e
# Out:
#               Name            Team    Number  Position       Age    Height  \
# 0    Avery Bradley  Boston Celtics         0        PG        25       6-2
# 1      Jae Crowder  Boston Celtics        99        SF        25       6-6
# 2     John Holland  Boston Celtics        30        SG        27       6-5
# 3      R.J. Hunter  Boston Celtics        28        SG        22       6-5
# 4    Jonas Jerebko  Boston Celtics         8        PF        29      6-10
# ..             ...             ...       ...       ...       ...       ...
# 453   Shelvin Mack       Utah Jazz         8        PG        26       6-3
# 454      Raul Neto       Utah Jazz        25        PG        24       6-1
# 455   Tibor Pleiss       Utah Jazz        21         C        26       7-3
# 456    Jeff Withey       Utah Jazz        24         C        26       7-0
# 457       no value        no value  no value  no value  no value  no value
#
#        Weight            College       Salary
# ...
