# %%
import pandas as pd
df = pd.read_csv("D:\\data science\\pandas\\csv\\nba.csv")
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df1 = pd.read_csv("D:\\data science\\pandas\\csv\\nba1.csv")
df1
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
a = pd.concat([df,df1],ignore_index=True)
a
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 0      Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1        Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2       John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3        R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4      Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..               ...             ...     ...      ...   ...    ...     ...
# 466     Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 467     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 468  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 469    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# 470      Evan Turner  Boston Celtics    11.0       SG  27.0    6-7   220.0
#
#                College     Salary
# ...

# %%
b = df.head()
b
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
c = df1.head()
c
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
d = pd.concat([b,c],ignore_index=False,axis=0,keys=["name1","name2"])
d
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# name1 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#       1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#       2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#       3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#       4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# name2 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#       1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#       2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#       3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#       4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                    College     Salary
# name1 0              Texas  7730337.0
#       1          Marquette  6796117.0
# ...

# %%
e = pd.read_csv("D:\\data science\\pandas\\csv\\weather.csv")
e
# Out:
#            day      city  temparature  windspeed    event
# 0   01-01-2017  new york           32           6    rain
# 1   01-02-2017  new york           36           7   sunny
# 2   01-03-2017  new york           33          12    snow
# 3   01-04-2017  new york           90           7   sunny
# 4   01-01-2017    mumbai           85           5   sunny
# 5   01-02-2017    mumbai           87          12     fog
# 6   01-03-2017    mumbai           92          15     fog
# 7   01-04-2017    mumbai           45           5    rain
# 8   01-01-2017     paris           50          20   sunny
# 9   01-02-2017     paris           54          13  cloudy
# 10  01-03-2017     paris           42           8  cloudy
# 11  01-04-2017     paris           47          10  cloudy

# %%
f = d.append(e)
f
# Out:
#                      Name            Team  Number Position   Age Height  \
# (name1, 0)  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# (name1, 1)    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# (name1, 2)   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# (name1, 3)    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# (name1, 4)  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# (name2, 0)  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# (name2, 1)    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# (name2, 2)   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# (name2, 3)    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# (name2, 4)  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 0                     NaN             NaN     NaN      NaN   NaN    NaN
# 1                     NaN             NaN     NaN      NaN   NaN    NaN
# ...

# %%
# %matplotlib inline
df.plot()

# %%
df1.plot()

# %%
a.plot()

# %%
b.plot()

# %%
c.plot()
