# %%
import pandas as pd
df = pd.read_csv("D:\\data science\\pandas\\csv\\nba-2.csv",index_col ="Name")
df.head()
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# John Holland   Boston University        NaN
# R.J. Hunter        Georgia State  1148640.0
# Jonas Jerebko                NaN  5000000.0

# %% [markdown]
# <font size="5"><font color="red">now lets work with indexing of pandas DataFrames

# %%
a=df.iloc[1:4,[3,4]]
a
# Out:
#                Age Height
# Name
# Jae Crowder   25.0    6-6
# John Holland  27.0    6-5
# R.J. Hunter   22.0    6-5

# %%
# %matplotlib inline
a.plot()

# %%
df.plot()

# %%
b=df.iloc[[416][:]]
b
# Out:
#                                Team  Number Position   Age Height  Weight  \
# Name
# Josh Huestis  Oklahoma City Thunder    34.0       SF  24.0    6-7   230.0
#
#                College     Salary
# Name
# Josh Huestis  Stanford  1140240.0

# %%
b.plot()

# %%
b=df.tail()
b
# Out:
#                    Team  Number Position   Age Height  Weight College  \
# Name
# Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# Raul Neto     Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# Jeff Withey   Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# NaN                 NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#                  Salary
# Name
# Shelvin Mack  2433333.0
# Raul Neto      900000.0
# Tibor Pleiss  2900000.0
# Jeff Withey    947276.0
# NaN                 NaN

# %%
b.plot()

# %%
c = df
c.plot()

# %%
df.drop(["Avery Bradley"],inplace=True)
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College      Salary
# Name
# Jae Crowder            Marquette   6796117.0
# John Holland   Boston University         NaN
# ...

# %%
df.drop(["Shelvin Mack","Jonas Jerebko"],inplace=True)
df
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Amir Johnson   Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ...                       ...     ...      ...   ...    ...     ...
# Trey Lyles          Utah Jazz    41.0       PF  20.0   6-10   234.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College      Salary
# Name
# Jae Crowder            Marquette   6796117.0
# John Holland   Boston University         NaN
# ...

# %%
df.drop(["Team","Number"],inplace=True,axis=1)
df
# Out:
#               Position   Age Height  Weight            College      Salary
# Name
# Jae Crowder         SF  25.0    6-6   235.0          Marquette   6796117.0
# John Holland        SG  27.0    6-5   205.0  Boston University         NaN
# R.J. Hunter         SG  22.0    6-5   185.0      Georgia State   1148640.0
# Amir Johnson        PF  29.0    6-9   240.0                NaN  12000000.0
# Jordan Mickey       PF  21.0    6-8   235.0                LSU   1170960.0
# ...                ...   ...    ...     ...                ...         ...
# Trey Lyles          PF  20.0   6-10   234.0           Kentucky   2239800.0
# Raul Neto           PG  24.0    6-1   179.0                NaN    900000.0
# Tibor Pleiss         C  26.0    7-3   256.0                NaN   2900000.0
# Jeff Withey          C  26.0    7-0   231.0             Kansas    947276.0
# NaN                NaN   NaN    NaN     NaN                NaN         NaN
#
# [455 rows x 6 columns]
