# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("D:\\data science\\pandas\\csv\\expense.csv")
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %%
a = df[df["Mthly_HH_Income"]>40000]
a
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 28            42000             15000                  4                0
# 29            43000             12000                  4                0
# 30            45000             25000                  6                0
# 31            45000             40000                  6             3500
# 32            45000             10000                  2             1000
# 33            45000             22000                  4             2500
# 34            46000             25000                  5             3500
# 35            47000             15000                  7                0
# 36            50000             20000                  4                0
# 37            50500             20000                  3                0
# 38            55000             45000                  6            12000
# 39            60000             10000                  3                0
# ...

# %%
b = list(df.iloc[28])

# %%
print(b)
type(b)
# Out:
# [42000, 15000, 4, 0, 488880, 'Graduate', 1]
# list

# %%
income = b[0]
expense = b[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
# Out:
# savings is: 27000
# income is: 42000

# %%
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()

# %%
c = list(df.iloc[1])
income = c[0]
expense = c[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: -1000
# income is: 6000

# %%
d = list(df.iloc[2])
income = d[0]
expense = d[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 5500
# income is: 10000

# %%
e = list(df.iloc[3])
income = e[0]
expense = e[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 8000
# income is: 10000

# %%
f = list(df.iloc[4])
income = f[0]
expense = f[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 500
# income is: 12500

# %%
g = list(df.iloc[5])
income = g[0]
expense = g[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 6000
# income is: 14000

# %%
h = list(df.iloc[6])
income = h[0]
expense = h[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: -1000
# income is: 15000

# %%
i = list(df.iloc[7])
income = i[0]
expense = i[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: -2000
# income is: 18000

# %%
j = list(df.iloc[8])
income = j[0]
expense = j[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 10000
# income is: 19000

# %%
k = list(df.iloc[9])
income = k[0]
expense = k[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 11000
# income is: 20000

# %%
l = list(df.iloc[10])
income = l[0]
expense = l[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 2000
# income is: 20000

# %%
m = list(df.iloc[11])
income = m[0]
expense = m[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: -3000
# income is: 22000

# %%
n = list(df.iloc[12])
income = n[0]
expense = n[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 18400
# income is: 23400

# %%
o = list(df.iloc[13])
income = o[0]
expense = o[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 13500
# income is: 24000

# %%
p = list(df.iloc[14])
income = p[0]
expense = p[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 14000
# income is: 24000

# %%
q = list(df.iloc[15])
income = q[0]
expense = q[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 12700
# income is: 25000

# %%
r = list(df.iloc[16])
income = r[0]
expense = r[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 5000
# income is: 25000

# %%
s = list(df.iloc[17])
income = r[0]
expense = r[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 5000
# income is: 25000

# %%
t = list(df.iloc[18])
income = t[0]
expense = t[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 22400
# income is: 29000

# %%
u = list(df.iloc[19])
income = u[0]
expense = u[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 17000
# income is: 30000

# %%
v = list(df.iloc[20])
income = v[0]
expense = v[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 5500
# income is: 30500

# %%
w = list(df.iloc[21])
income = w[0]
expense = w[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 17000
# income is: 32000

# %%
x = list(df.iloc[22])
income = x[0]
expense = x[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 15000
# income is: 34000

# %%
y = list(df.iloc[23])
income = y[0]
expense = y[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 9000
# income is: 34000

# %%
z = list(df.iloc[24])
income = z[0]
expense = z[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 23000
# income is: 35000

# %%
A = list(df.iloc[25])
income = A[0]
expense = A[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 10000
# income is: 35000

# %%
B = list(df.iloc[26])
income = B[0]
expense = B[1]
savings = income - expense
print("savings is:",savings)
print("income is:",income)
values = [income,expense,savings]
label = ["income","expense","savings"]
plt.pie(values,labels=label,autopct='%f',colors=["red","yellow","blue"],radius=1.5,shadow=True,explode=[0,0.3,0])
plt.show()
# Out:
# savings is: 31000
# income is: 39000

# %% [markdown]
# <font size=10>now lets find average
